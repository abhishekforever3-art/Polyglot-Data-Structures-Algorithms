# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
#
# **Unsupervised Learning: Discovering Hidden Patterns**
#
# Unsupervised learning extracts insights from unlabeled data by identifying inherent structures. Key approaches include:
#
# **1. Dimension Reduction** (e.g., PCA, t-SNE)
#
# 1. Compresses data while preserving essential features.
# 2. Example: Visualizing high-dimensional data in 2D.
#
# **2. Clustering** (e.g., K-Means, Hierarchical)
#
# 1. Groups similar data points into clusters.
# 2. Example: *Customer segmentation for targeted marketing.*
#
# **3. Association** (e.g., Apriori, FP-Growth)
#
# 1. Discovers co-occurrence patterns (e.g., "Customers who buy X also buy Y").
#
# *"Among these, clustering is widely used to uncover natural groupings in data. Let's dive deeper!"*

# %% [markdown]
# # Types of Machine Learning
#
# ## Classical Machine Learning
#
# ### Task Driven → Supervised Learning
#
# (Pre Categorized Data)
#
# 1. Classification
#
#    * Divide the socks by Color
#
#    * Example: Identity Fraud Detection
#
# 2. Regression
#
#    * Divide the Ties by Length
#
#    * Example: Market Forecasting
#
# ### Data Driven → Unsupervised Learning
#
# (Unlabelled Data)
#
# 1. Clustering
#
#    * Divide by Similarity
#
#    * Example: Targeted Marketing
#
# 2. Association
#
#    * Identify Sequences
#
#    * Example: Customer Recommendation
#
# 3. Dimensionality Reduction
#
#    * (Wider Dependencies — partially obscured in the image)
#
#    * Example: Big Data Visualization
#
# ### Objective
#
# * Supervised Learning: Predictions & Predictive Models
#
# * Unsupervised Learning: Pattern / Structure Recognition

# %% [markdown]
# # What is Clustering?
#
# * Clustering is a method of organizing data points into clusters or groups that share similarities.
#
# * Data points with similar characteristics are grouped together while data points with dissimilar characteristics are placed in different clusters.
#
#
# * Raw Data
#
# * Algorithm
#
# * Output

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Clustering - case study
#
# * **Definition:** Clustering is the process of dividing the entire data into groups (also known as clusters) based on the patterns in the data.
# * **Example Scenario:** Let's see a simple example. A bank wants to give credit card offers to its customers. Currently, they look at the details of each customer and based on this information, decide which offer should be given to which customer.
# * **The Challenge:** Now, the bank can potentially have millions of customers. Does it make sense to look at the details of each customer separately and then make a decision? Certainly not!

# %% [markdown]
# # What is Clustering? (contd.)
#
# It is a manual process and will take a huge amount of time.
#
# So what can the bank do? One option is to segment its customers into different groups. For instance, the bank can group the customers based on their income:
#
# The bank can now make three different strategies or offers, one for each group. Here, instead of creating different strategies for individual customers, they only have to make 3 strategies.

# %% [markdown]
# ## What is Clustering? (contd.)
#
# * The groups shown above are known as **clusters** and the process of creating these groups is known as **clustering**.
# * **Formally, we can say that:**
# * **Clustering** is the process of dividing the entire data into groups (also known as clusters) based on the patterns in the data.

# %% [markdown]
# ## Clustering is Unsupervised ML
#
# * Now, there might be situations where we do not have any target variable to predict.
# * Such problems, without any fixed target variable, are known as unsupervised learning problems.
# * In these problems, we only have the independent variables and no target/dependent variable.
# * In clustering, we do not have a target to predict. We look at the data and then try to club similar observations and form different groups. Hence it is an unsupervised learning problem.

# %% [markdown]
# ## Applications of Clustering in Real-World Scenarios
#
# * **Customer Segmentation**
# * Group customers based on purchasing behavior to personalize marketing and improve customer retention.
# * *Example:* E-commerce platforms like Amazon.
#
#
# * **Market Basket Analysis**
# * Identify product groupings that are often bought together.
# * *Example:* Retail chains optimizing store layouts.
#
#
# * **Image Segmentation**
# * Divide an image into regions for object detection and recognition.
# * *Example:* Medical imaging to detect tumors.
#
#
# * **Social Network Analysis**
# * Find communities or influencer groups in a network.
# * *Example:* Facebook or LinkedIn community detection.
#
#
# * **Anomaly Detection**
# * Identify outliers or fraud in financial transactions.
# * *Example:* Credit card fraud detection.
#
#
# * **Document or News Categorization**
# * Group similar documents or articles for topic modeling.
# * *Example:* News aggregators like Google News.

# %% [markdown]
# ## Properties of Clusters
#
# * We’ll take the same bank as before who wants to segment its customers.
# * For simplicity purposes, let’s say the bank only wants to use the income and debt to make the segmentation.
# * They collected the customer data and used a scatter plot to visualize it:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * On the X-axis, we have the income of the customer and the y-axis represents the amount of debt.
# * Here, we can clearly visualize that these customers can be segmented into 4 different clusters as shown below:
# * This is how clustering helps to create segments (clusters) from the data. The bank can further use these clusters to make strategies and offer discounts to its customers. So let's look at the properties of these clusters.

# %% [markdown]
# ## Properties of Clusters
#
# ### Property 1
#
# All the data points in a cluster should be similar to each other.
# Let me illustrate it using the above example:
#
# * If the customers in a particular cluster are not similar to each other, then their requirements might vary, right?
# * If the bank gives them the same offer, they might not like it and their interest in the bank might reduce. Not ideal.

# %% [markdown]
# ## Properties of Clusters
#
# ### Property 2
#
# The data points from different clusters should be as different as possible. This will intuitively make sense if you grasped the above property. Let's again take the same example to understand this property:
#
# * **Question:** Which of these cases do you think will give us the better clusters?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Which of these cases do you think will give us the better clusters? (CASE I)
#
# * Customers in the red and blue clusters are quite similar to each other.
# * The top four points in the red cluster share similar properties as that of the top two customers in the blue cluster.
# * They have high income and high debt value. Here, we have clustered them differently.

# %% [markdown]
# ## Which of these cases do you think will give us the better clusters (CASE II)?
#
# * Points in the red cluster are completely different from the customers in the blue cluster.
# * All the customers in the red cluster have high income and high debt and customers in the blue cluster have high income and low debt value.
# * Clearly, we have a better cluster of customers in this case.

# %% [markdown]
# ## Inertia
#
# * Recall the first property of clusters we covered above. This is what inertia evaluates. It tells us how far the points within a cluster are. So, inertia actually calculates the sum of distances of all the points within a cluster from the centroid of that cluster.
# * We calculate this for all the clusters and the final inertial value is the sum of all these distances. This distance within the clusters is known as intracluster distance. So, inertia gives us the sum of intracluster distances:

# %% [markdown]
# ## Two Main Types of Clustering Algorithms
#
# | Type | Example Algorithm | Key Concept | Use When... |
# | --- | --- | --- | --- |
# | **Partitioning-Based** | K-Means | Divides data into **K clusters** by minimizing intra-cluster distance | You know the number of clusters (K) |
# | **Hierarchical-Based** | Agglomerative | Builds a **tree (dendrogram)** by merging or splitting clusters | You want to see cluster hierarchy |

# %% [markdown]
# ## Introduction to K-Means Clustering
#
# * Recall the first property of clusters – it states that the points within a cluster should be similar to each other. So, our aim here is to minimize the distance between the points within a cluster.
# * There is an algorithm that tries to minimize the distance of the points in a cluster with their centroid – the k-means clustering technique.
# * **K-means** is a centroid-based algorithm, or a distance-based algorithm, where we calculate the distances to assign a point to a cluster. In K-Means, each cluster is associated with a centroid.
# * The main objective of the K-Means algorithm is to minimize the sum of distances between the points and their respective cluster centroid.

# %% [markdown]
# ## Step - by Step calculation behind K-Means Clustering
#
# The working of the K-Means algorithm is explained in the below steps:
#
# * **Step-1:** Select the number K to decide the number of clusters.
# * **Step-2:** Select random K points or centroids.
# * **Step-3:** Assign each data point to their closest centroid, which will form the predefined K clusters.
# * **Step-4:** Calculate the variance and place a new centroid of each cluster.
# * **Step-5:** Repeat the third step, which means reassign each datapoint to the new closest centroid of each cluster.
# * **Step-6:** If any reassignment occurs, then go to step-4 else go to FINISH.
# * **Step-7:** The model is ready.

# %% [markdown]
# * **Objective:** Demonstrate the working of K-Means Clustering using a small sample dataset for clear understanding.
# * **Sample Data Points (2D):** We have 6 data points in 2D space:
# * $P1 = (1, 1)$
# * $P2 = (1.5, 2)$
# * $P3 = (3, 4)$
# * $P4 = (5, 7)$
# * $P5 = (3.5, 5)$
# * $P6 = (4.5, 5)$
#
#
# * **Target Clusters:** We want to divide them into $K = 2$ clusters.

# %% [markdown]
# ## Step 1: Select Initial Centroids
#
# * We randomly select 2 points as our initial centroids:
# * **$C_1 = P_1 = (1, 1)$**
# * **$C_2 = P_4 = (5, 7)$**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 2: Assign Data Points to Nearest Centroid
#
# Use Euclidean distance to assign each point to the nearest centroid.
#
# Distances from C1 (1,1):
#
# * P1: 0
# * P2: sqrt((1.5 - 1)^2 + (2 - 1)^2) = 1.12
# * P3: sqrt(2^2 + 3^2) = 3.61
# * (3 - 1) = 2, (4 - 1) = 3

# %% [markdown]
# * P4: sqrt(4^2 + 6^2) = 7.21
# * P5: sqrt(2.5^2 + 4^2) = 4.72
# * P6: sqrt(3.5^2 + 4^2) = 5.32
#
# **Distances from C2 (5,7):**
#
# * P1: 7.21
# * P2: 6.10
# * P3: 3.61
# * P4: 0
# * P5: 2.50
# * P6: 2.06
#
# **Cluster Assignments:**
#
# * Cluster 1 (C1): P1, P2
# * Cluster 2 (C2): P3, P4, P5, P6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Step 3: Recalculate Centroids
#
# Compute new centroid for each cluster.
#
# **New C1:** Mean of P1, P2:
#
# * x = (1 + 1.5) / 2 = 1.25
# * y = (1 + 2) / 2 = 1.5
# * New C1 = (1.25, 1.5)
#
# **New C2:** Mean of P3, P4, P5, P6:
#
# * x = (3 + 5 + 3.5 + 4.5) / 4 = 4
# * y = (4 + 7 + 5 + 5) / 4 = 5.25
# * New C2 = (4, 5.25)
#
# Step 4: Reassign Data Points Based on New Centroids

# %% [markdown]
# Distances to new C1 (1.25, 1.5):
#
# * P1: 0.56
# * P2: 0.35
# * P3: 3.20
# * P4: 6.10
# * P5: 3.35
# * P6: 3.91
#
# **Distances to new C2 (4, 5.25):**
#
# * P1: 5.25
# * P2: 4.30
# * P3: 1.39
# * P4: 2.21
# * P5: 0.79
# * P6: 0.79
#
# updated clusters:
#
# * Cluster 1: P1, P2
# * Cluster 2: P3, P4, P5, P6
#
# **Step 5: Check for Convergence**
#
# Since the cluster assignments haven't changed from the last step, K-Means has converged.
#
# **Final Result:**
#
# * Cluster 1: P1, P2 $\rightarrow$ Centroid: (1.25, 1.5)
# * Cluster 2: P3, P4, P5, P6 $\rightarrow$ Centroid: (4, 5.25)

# %% [markdown]
# ## How to determine correct number of clusters (k)?

# %% [markdown]
# ## SSE vs K: Choosing Optimal K in K-Means Clustering
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How to select best value of $k$
#
# Now, we will increase the number of clusters, train the model again, and plot the inertia value. This is the plot we get:
#
# * **Inertia vs. $K$ Plot:** Shows a sharp decrease in inertia at lower values of $K$, creating an "elbow" shape where the curve flattens out.
# * **Computation Cost Note:** You must also look at the computation cost while deciding the number of clusters. If we increase the number of clusters, the computation cost will also increase.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## K-Means Clustering Model Evaluation Technique
#
# * **Definition:** The silhouette score is a measure of how similar an object is to its own cluster compared to other clusters. It provides a way to assess the quality of clustering results in unsupervised learning.
# * **Components for each data point $i$:**
# * $a(i)$: The average distance between $i$ and all other points in the same cluster.
# * $b(i)$: The minimum average distance between $i$ and all points in any other cluster of which $i$ is not a member.
#
#
# * **Silhouette Score Formula:**
# For a single data point $i$, the score $s(i)$ is calculated as:
#
# $$s(i) = \frac{b(i) - a(i)}{\max(a(i), b(i))}$$

# %% [markdown]
# ## K-Means Clustering Model Evaluation Technique
#
# The silhouette score ranges from -1 to 1:
#
# * **+1:** Indicates that the sample is far away from the neighboring clusters and well matched to its own cluster.
# * **0:** Indicates that the sample is on or very close to the decision boundary between two neighboring clusters.
# * **-1:** Indicates that the sample might have been assigned to the wrong cluster.
#
# It's time to implement in Python.
